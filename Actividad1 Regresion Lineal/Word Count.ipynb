# %%
# Imports necesarios
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
# %matplotlib inline
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
plt.rcParams['figure.figsize'] = (16, 9)
plt.style.use('ggplot')
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %%
data = pd.read_csv("./articulos_ml.csv")

# %%
data.shape
# Out:
# (161, 8)

# %%
data.head()
# Out:
#                                                Title  \
# 0  What is Machine Learning and how do we use it ...
# 1   10 Companies Using Machine Learning in Cool Ways
# 2  How Artificial Intelligence Is Revolutionizing...
# 3  Dbrain and the Blockchain of Artificial Intell...
# 4  Nasa finds entire solar system filled with eig...
#
#                                                  url  Word count  # of Links  \
# 0  https://blog.signals.network/what-is-machine-l...        1888           1
# 1                                                NaN        1742           9
# 2                                                NaN         962           6
# 3                                                NaN        1221           3
# 4                                                NaN        2039           1
#
#    # of comments  # Images video  Elapsed days  # Shares
# 0            2.0               2            34    200000
# 1            NaN               9             5     25000
# ...

# %%
data.describe()
# Out:
#         Word count  # of Links  # of comments  # Images video  Elapsed days  \
# count   161.000000  161.000000     129.000000      161.000000    161.000000
# mean   1808.260870    9.739130       8.782946        3.670807     98.124224
# std    1141.919385   47.271625      13.142822        3.418290    114.337535
# min     250.000000    0.000000       0.000000        1.000000      1.000000
# 25%     990.000000    3.000000       2.000000        1.000000     31.000000
# 50%    1674.000000    5.000000       6.000000        3.000000     62.000000
# 75%    2369.000000    7.000000      12.000000        5.000000    124.000000
# max    8401.000000  600.000000     104.000000       22.000000   1002.000000
#
#             # Shares
# count     161.000000
# mean    27948.347826
# std     43408.006839
# min         0.000000
# 25%      2800.000000
# 50%     16458.000000
# 75%     35691.000000
# max    350000.000000

# %%
data.drop(['Title','url', 'Elapsed days'],axis=1).hist()
plt.show()

# %%
colores=['orange','blue']
tamanios=[30,60]
f1 = data['Word count'].values
f2 = data['# Shares'].values
asignar=[]
for index, row in data.iterrows():
    if(row['Word count']>1808):
        asignar.append(colores[0])
    else:
        asignar.append(colores[1])

plt.scatter(f1, f2, c=asignar, s=tamanios[0])
plt.show()

# %%
filtered_data = data[(data['Word count'] <= 3500) & (data['# Shares'] <= 80000)]
f1 = filtered_data['Word count'].values
f2 = filtered_data['# Shares'].values
# Vamos a pintar en colores los puntos por debajo y por encima de la media de Cantidad de Palabras
asignar=[]
for index, row in filtered_data.iterrows():
    if(row['Word count']>1808):
        asignar.append(colores[0])
    else:
        asignar.append(colores[1])

plt.scatter(f1, f2, c=asignar, s=tamanios[0])
plt.show()

# %%
filtered_data.describe()
# Out:
#         Word count  # of Links  # of comments  # Images video  Elapsed days  \
# count   148.000000  148.000000     121.000000      148.000000    148.000000
# mean   1640.209459    5.743243       7.256198        3.331081     91.554054
# std     821.975365    6.064418       6.346297        2.706476     91.143923
# min     250.000000    0.000000       0.000000        1.000000      1.000000
# 25%     971.000000    3.000000       2.000000        1.000000     28.750000
# 50%    1536.000000    5.000000       6.000000        3.000000     60.000000
# 75%    2335.750000    7.000000      11.000000        4.000000    110.500000
# max    3485.000000   49.000000      30.000000       22.000000    349.000000
#
#            # Shares
# count    148.000000
# mean   20545.648649
# std    19933.865031
# min        0.000000
# 25%     2750.000000
# 50%    15836.000000
# 75%    34177.500000
# max    77000.000000

# %%
dataX =filtered_data[["Word count"]]
X_train = np.array(dataX)
y_train = filtered_data['# Shares'].values

# %%
# Creamos el objeto de Regresión Linear
regr = linear_model.LinearRegression()
# Entrenamos nuestro modelo
regr.fit(X_train, y_train)
# Hacemos las predicciones que en definitiva una línea (en este caso, al ser 2D)
y_pred = regr.predict(X_train)
# Veamos los coeficienetes obtenidos, En nuestro caso, serán la Tangente
print('Coefficients: \n', regr.coef_)
# Este es el valor donde corta el eje Y (en X=0)
print('Independent term: \n', regr.intercept_)
# Error Cuadrado Medio
print("Mean squared error: %.2f" % mean_squared_error(y_train, y_pred))
# Puntaje de Varianza. El mejor puntaje es un 1.0
print('Variance score: %.2f' % r2_score(y_train, y_pred))
# Out:
# Coefficients:
#  [5.69765366]
# Independent term:
#  11200.303223074163
# Mean squared error: 372888728.34
# Variance score: 0.06

# %%
plt.scatter(X_train[:,0], y_train, c=asignar, s=tamanios[0])
plt.plot(X_train[:,0], y_pred, color='red', linewidth=3)
plt.xlabel('Cantidad de Palabras')
plt.ylabel('Compartido en Redes')
plt.title('Regresión Lineal')
plt.show()

# %%
y_Dosmil = regr.predict([[2000]])
print(int(y_Dosmil))
# Out:
# 22595
# C:\Users\alexi\AppData\Local\Temp\ipykernel_2656\452605552.py:2: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print(int(y_Dosmil))

# %%
# Vamos a intentar mejorar el Modelo, con una dimensión más:
# Para poder graficar en 3D, haremos una variable nueva que será la suma de los enlaces,
# comentarios e imágenes
suma = (filtered_data["# of Links"] + filtered_data['# of comments'].fillna(0) +
filtered_data['# Images video'])
dataX2 = pd.DataFrame()
dataX2["Word count"] = filtered_data["Word count"]
dataX2["suma"] = suma
XY_train = np.array(dataX2)
z_train = filtered_data['# Shares'].values

# %%
# Creamos un nuevo objeto de Regresión Lineal
regr2 = linear_model.LinearRegression()
# Entrenamos el modelo, esta vez, con 2 dimensiones
# obtendremos 2 coeficientes, para graficar un plano
regr2.fit(XY_train, z_train)
# Hacemos la predicción con la que tendremos puntos sobre el plano hallado
z_pred = regr2.predict(XY_train)
# Los coeficientes
print('Coefficients: \n', regr2.coef_)
# Error cuadrático medio
print("Mean squared error: %.2f" % mean_squared_error(z_train, z_pred))
# Evaluamos el puntaje de varianza (siendo 1.0 el mejor posible)
print('Variance score: %.2f' % r2_score(z_train, z_pred))
# Out:
# Coefficients:
#  [   6.63216324 -483.40753769]
# Mean squared error: 352122816.48
# Variance score: 0.11

# %%
fig = plt.figure()
#ax = Axes3D(fig)
ax = fig.add_subplot(111, projection='3d')
# Creamos una malla, sobre la cual graficaremos el plano
xx, yy = np.meshgrid(np.linspace(0, 3500, num=10), np.linspace(0, 60, num=10))
# calculamos los valores del plano para los puntos x e y
nuevoX = (regr2.coef_[0] * xx)
nuevoY = (regr2.coef_[1] * yy)
# calculamos los correspondientes valores para z. Debemos sumar el punto de intercepción
z = (nuevoX + nuevoY + regr2.intercept_)
# Graficamos el plano
ax.plot_surface(xx, yy, z, alpha=0.2, cmap='hot')
# Graficamos en azul los puntos en 3D
ax.scatter(XY_train[:, 0], XY_train[:, 1], z_train, c='blue',s=30)
# Graficamos en rojo, los puntos que
ax.scatter(XY_train[:, 0], XY_train[:, 1], z_pred, c='red',s=40)
# con esto situamos la "camara" con la que visualizamos
ax.view_init(elev=30., azim=65)

ax.set_xlabel('Cantidad de Palabras')
ax.set_ylabel('Cantidad de Enlaces,Comentarios e Imagenes')
ax.set_zlabel('Compartido en Redes')
ax.set_title('Regresión Lineal con Múltiples Variables')
plt.show()

# %%
z_Dosmil = regr2.predict([[2000, 10+4+6]])
print(int(z_Dosmil))
# Out:
# 20518
# C:\Users\alexi\AppData\Local\Temp\ipykernel_2656\3648231557.py:2: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print(int(z_Dosmil))

# %%
mejoraEnError = mean_squared_error(y_train, y_pred) - mean_squared_error(z_train, z_pred)
print(mejoraEnError)
# Out:
# 20765911.860715985

# %%
mejoraEnVarianza = r2_score(z_train, z_pred) - r2_score(y_train, y_pred)
print(mejoraEnVarianza)
# Out:
# 0.052615337462582956

# %%
diferenciaComparir = z_Dosmil - y_Dosmil
print(int(diferenciaComparir))
# Out:
# -2077
# C:\Users\alexi\AppData\Local\Temp\ipykernel_2656\703031493.py:2: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print(int(diferenciaComparir))

# %% [markdown]
# ### ¿Por qué era importante evaluar si existe una relación entre la cantidad de palabras y la cantidad de shares de un artículo?
# Era de relevancia porque puede ser que la cantidad de palabras y la cantidad de shares estén linealmente correlacionadas, porque la cantidad de palabras puede funcionar como una variable predictora que puede servir para explicar o estimar la variable objetivo que es cantidad de shares. Y siempre es importante hacer una evaluación de las variables para ver si hay algún tipo de correlación entre palabras y shares.

# %% [markdown]
# ### Al analizar los histogramas iniciales, ¿qué patrones observaste en la distribución de palabras y shares? ¿Cómo influye esto en la selección del modelo?
# Visualizando los datos así de manera cruda por medio de los histogramas se pudo considerar de que al tener un Word count menor hay más shares, se concentran en los valores bajos, con pocos artículos teniendo valores extremadamente altos.
# El patrón indica que un modelo lineal simple puede ser útil como primera aproximación.

# %% [markdown]
# ### ¿Qué propósito tuvo filtrar los artículos con menos de 3500 palabras y menos de 80,000 shares? ¿Cómo cambió el comportamiento del modelo después del filtrado?
# El propósito del filtrado fue que nos enfoquemos en la zona donde se concentran muchos más registros y tratar de evitar situaciones muy extremas que pueden distorsionar el ajuste del modelo.
# Después del filtrado se pudo ver que la nube de puntos se volvió mucho más compacta y más representativa del comportamiento típico y también la regresión dejó de estar “jalada” por artículos extremadamente virales o extremadamente largos.

# %% [markdown]
# ### ¿Por qué crees que había tanta concentración de puntos en estas zonas? ¿Cómo afecta esto al desempeño de la regresión lineal?
# Consideraría que es porque los artículos que hay en internet siempre tienen un promedio o un tamaño medio, no miles de palabras que son como casos extremos. La regresión lineal intenta “promediar” el comportamiento general. Cuando hay una concentración masiva en una región, el modelo se ajusta más a esa zona, pero cuando la nube es demasiado dispersa, la línea no explica nada y las predicciones se vuelven poco confiables.

# %% [markdown]
# ### En el modelo de regresión simple, ¿qué significa la pendiente del modelo respecto a la relación Word Count → Shares? Explica en tus palabras.
# La pendiente indica cuanto aumentan o disminuyen los shares en promedio cuando aumenta el número de palabras del artículo, todo eso depende del signo que tenga la pendiente.

# %% [markdown]
# ### El error cuadrático medio (MSE) fue alto en el primer modelo. ¿Qué factores en los datos podrían explicar este resultado?
# El MSE alto se puede explicar por varios factores que hay en los datos:
#
# •	Alta dispersión: para un mismo Word count hay artículos con shares muy distintos.
#
# •	Outliers y viralidad: algunos artículos se disparan en shares por razones que no dependen solo de palabras.
#
# •	Relación no lineal o débil: aunque la pendiente sea positiva, no necesariamente significa que Word count sea la causa principal.

# %% [markdown]
# ### Observa el R² obtenido: ¿Crees que la cantidad de palabras es un buen predictor de los shares? ¿Por qué sí o por qué no?
# Como el R² obtenido es bajo, consideraría que aunque haya una ligera tendencia, la cantidad de palabras no explica bien por sí sola cuántos shares tendrá un artículo, tal vez hayan más datos que sean mucho más útiles.

# %% [markdown]
# ### En los gráficos que distinguen artículos por encima y por debajo de la media (1808 palabras), ¿qué diferencias observaste en la dispersión?
# Los artículos más largos presentan dispersión más amplia, lo que sugiere que la longitud por sí sola no controla el éxito, pero sí podría asociarse a más potencial de shares.

# %% [markdown]
# ### ¿Te parece que la línea de regresión se ajusta bien a los datos? Argumenta basándote en la dispersión.
# Consideraría que el ajuste no es bueno, aunque se vea que hay una línea con pendiente positiva, se puede ver que hay muchos puntos muy alejados de la línea, para valores similares de Word count hay shares muy diferentes. La regresión lineal simple sirve como aproximación inicial y visual, pero no logra representar adecuadamente el fenómeno debido a la dispersión y a factores adicionales que influyen en la viralidad del artículo.
